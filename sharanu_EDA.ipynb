# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel("/content/EDA_Employee_Salary_Data (2).xlsx")

print(df.head())
# Out:
#    EmployeeID   Name  Age  Gender Department  Experience_Years  Salary  \
# 0        1001   Amit   55  Female         HR                15   34974
# 1        1002  Sneha   40  Female      Sales                 7   73226
# 2        1003   John   46    Male         HR                 8   62539
# 3        1004   Neha   22    Male      Sales                 7   67216
# 4        1005  Kiran   38    Male  Marketing                30   80640
#
#         City
# 0  Hyderabad
# 1      Delhi
# 2      Delhi
# 3      Delhi
# 4    Chennai

# %%
plt.figure()
df['Department'].value_counts().plot(kind='bar')
plt.title("Employee Count by Department")
plt.xlabel("Department")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure()
df['Gender'].value_counts().plot(
    kind='pie',
    autopct='%1.1f%%',
    startangle=90
)
plt.title("Gender Distribution")
plt.ylabel("")  # remove y-label
plt.show()

# %%
plt.figure()
numeric_df = df.select_dtypes(include=['int64', 'float64'])
sns.heatmap(numeric_df.corr(), annot=True)
plt.title("Correlation Heatmap")
plt.show()

# %%
plt.figure()
sns.histplot(df['Salary'], bins=20, kde=True)
plt.title("Salary Distribution")
plt.xlabel("Salary")
plt.ylabel("Frequency")
plt.show()

# %%
plt.figure()
sns.lineplot(x=df.index, y=df['Salary'])
plt.title("Salary Trend")
plt.xlabel("Index")
plt.ylabel("Salary")
plt.show()
